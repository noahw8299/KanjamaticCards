# %%
import pandas as pd
import re
from jisho_api.sentence import Sentence
from jisho_api.word import Word
from sudachipy import tokenizer
from sudachipy import dictionary
from wanakana import to_hiragana, is_japanese, is_katakana, is_hiragana, is_kanji
from deep_translator import (ChatGptTranslator, GoogleTranslator)
import string

# %%
tokenizer_obj = dictionary.Dictionary(dict_type="small").create()

KANJI_READING_MAPPING = {
    '私': '私[わたし]',
    '貴女': '貴女[あなた]',
    '何': '何[なに]',
    '外宇宙': '外宇宙[がいうちゅう]',
    '異星人': '異星人[いせいじん]',
    '優那': '優那[ゆうな]',
    '菜々美': '菜々美[ななみ]'
}

JAPANESE_PUNCTUATION = '　〜！？。、（）：「」『』０１２３４５６７８９ａｂｃｄｅｆｇｈｉｊｋｌｍｎｏｐｑｒｓｔｕｖｗｘｙｚＡＢＣＤＥＦＧＨＩＪＫＬＭＮＯＰＱＲＳＴＵＶＷＸＹＺ'

SPECIAL_CHARACTERS = '〜'

def is_japanese_extended(text):
    return is_japanese(text) and text not in string.punctuation and text not in JAPANESE_PUNCTUATION

def to_anki_format(index, kanji, reading):
    return '{}{}[{}]'.format(' ' if index > 0 else '', kanji, reading) 

def add_furigana(text):
    tokens = [m for m in tokenizer_obj.tokenize(text, tokenizer.Tokenizer.SplitMode.C)]
    parsed = ''
    token_indexes_to_skip = []
    for index, token in enumerate(tokens):   
        if index in token_indexes_to_skip:
          continue
        to_parse = is_japanese_extended(token.surface()) and not is_katakana(token.surface()) and not is_hiragana(token.surface())
        if to_parse:
            if token.surface()[-1] in SPECIAL_CHARACTERS:
                parsed += add_furigana(token.surface()[:-1]) + token.surface()[-1]
            else:
                if index > 0:
                    parsed += ' '
                reading = to_hiragana(token.reading_form())
                if token.surface() in KANJI_READING_MAPPING:
                    parsed += KANJI_READING_MAPPING[token.surface()]
                elif index < len(tokens)-1 and token.surface() + tokens[index+1].surface() in KANJI_READING_MAPPING:
                    parsed += KANJI_READING_MAPPING[tokens[index].surface() + tokens[index+1].surface()]
                    token_indexes_to_skip.append(index+1)
                else:
                    surface_index = 0
                    reading_index = 0
                    while len(token.surface()) > surface_index:
                        if is_hiragana(token.surface()[surface_index]) or is_katakana(token.surface()[surface_index]):
                            parsed += token.surface()[surface_index]
                            reading_index += 1
                            surface_index += 1
                        else:
                            next_index = -1
                            for token_index in range(surface_index, len(token.surface())):
                                if is_hiragana(token.surface()[token_index]) or is_katakana(token.surface()[token_index]):
                                    next_index = token_index
                                    break
                            if next_index < 0:
                                parsed += to_anki_format(
                                  index=surface_index, 
                                  kanji=token.surface()[surface_index:], reading=reading[reading_index:])
                                break
                            else:
                                reading_index_tail = reading_index
                                while reading[reading_index_tail] != token.surface()[next_index] or (reading_index_tail < len(reading)-1 and reading[reading_index_tail] == reading[reading_index_tail+1]):
                                    reading_index_tail += 1
                                parsed += to_anki_format(
                                  index=surface_index, 
                                  kanji=token.surface()[surface_index:next_index], reading=reading[reading_index:reading_index_tail])
                                reading_index = reading_index_tail
                            reading_length = next_index - surface_index
                            if reading_length > 0:
                                surface_index += reading_length
                            else:
                                break
        else:
            parsed += token.surface()
    return parsed
# Out:
# /var/folders/vt/st5d0xqj4vn9bjz3rgc4jhqc0000gn/T/ipykernel_69877/3941344110.py:1: DeprecationWarning: Parameter dict_type of Dictionary() is deprecated, use dict instead
#   tokenizer_obj = dictionary.Dictionary(dict_type="small").create()

# %%
def translate(word):
    return GoogleTranslator(source='japanese', target='english').translate(text=word)

# %%
def scrape_def(word):
    r = Word.request(word)
    result = ""
    for item in r.data[0].senses[0].english_definitions:
        result += f"{item}; "
    parts_of_speech = r.data[0].senses[0].parts_of_speech
    if len(parts_of_speech) == 1:
        return f"{parts_of_speech[0]}\n" + result[:-2]
    else:
        return f"{parts_of_speech[1]} - {parts_of_speech[0]}\n" + result[:-2]

# %%
def define_word(row):
    if pd.isna(row['Definition']):
        return scrape_def(row['Vocab'])
    else:
        return row['Definition']

# %%
def get_example(row):
    if pd.isna(row['Sentence']):
        r = Sentence.request(row['Vocab'])
        if r is not None:
            if r.data:  # Check if data is not empty
                for item in r.data:
                    #if row['Vocab'] in item.japanese:
                    sentence = item.japanese
                    no_furigana, furigana = replace_parentheses(sentence)
                    english = item.en_translation
                    return no_furigana, furigana, english
        return None, None, None  # Return None if no match found or no data
    elif pd.isna(row['Sentence_def']):
        return row['Sentence'], add_furigana(row['Sentence']), translate(row['Sentence'])
    else:
        return row['Sentence'], add_furigana(row['Sentence']), row['Sentence_def']

# %%
result = Sentence.request('湯気')
if result is not None:
    jisho_sentences = []

    # Accessing metadata
    status_code = result.meta.status

    # Accessing sentence data
    for sentence_config in result.data:
        japanese_sentence = sentence_config.japanese
        english_translation = sentence_config.en_translation

        jisho_sentences.append((japanese_sentence, english_translation))

    # Creating a DataFrame
    test = pd.DataFrame(jisho_sentences, columns=['Japanese Sentence', 'English Translation'])

# %%
def replace_parentheses(input_string):
    # Replace all parentheses with brackets
    brackets_replaced = input_string.replace('(', '[').replace(')', ']')

    # Remove parentheses and content within them using regular expressions
    parentheses_removed = re.sub(r'\([^)]*\)', '', input_string)

    return parentheses_removed, brackets_replaced

# %%
vocabulary = pd.read_csv('../../data/new_vocab.csv')
vocabulary
# Out:
#     Vocab  Definition  Sentence  Sentence_def
# 0     落とす         NaN       NaN           NaN
# 1     落ちる         NaN       NaN           NaN
# 2      出す         NaN       NaN           NaN
# 3      出る         NaN       NaN           NaN
# 4     入れる         NaN       NaN           NaN
# 5      入る         NaN       NaN           NaN
# 6     開ける         NaN       NaN           NaN
# 7      開く         NaN       NaN           NaN
# 8     閉める         NaN       NaN           NaN
# 9     閉まる         NaN       NaN           NaN
# 10    つける         NaN       NaN           NaN
# 11     つく         NaN       NaN           NaN
# 12     消す         NaN       NaN           NaN
# 13    消える         NaN       NaN           NaN
# 14     抜く         NaN       NaN           NaN
# 15    抜ける         NaN       NaN           NaN
# 16    割れる         NaN       NaN           NaN
# 17    破れる         NaN       NaN           NaN
# 18    痩せる         NaN       NaN           NaN
# 19   ずいぶん         NaN       NaN           NaN
# 20      布         NaN       NaN           NaN
# 21      袋         NaN       NaN           NaN
# 22    折れる         NaN       NaN           NaN
# 23     折る         NaN       NaN           NaN
# 24      歯         NaN       NaN           NaN
# 25    欠ける         NaN       NaN           NaN
# 26     張る         NaN       NaN           NaN
# 27    仕舞う         NaN       NaN           NaN
# 28    掛ける         NaN       NaN           NaN
# 29  ホッチキス         NaN       NaN           NaN

# %%
data = []
columns = ['index', 'word', 'word_with_reading', 'definition', 'example_sentence', 'sentence_with_reading', 'sentence_translation', 'Kanji', 'v1', 'word_audio', 'setence_audio']
df = pd.DataFrame(data, columns=columns)

# %%
df['index'] = vocabulary['Vocab']
df['word'] = vocabulary['Vocab']
df['word_with_reading'] = vocabulary['Vocab'].apply(add_furigana)
df['definition'] = vocabulary.apply(define_word, axis=1)

# Apply the function to each row of the DataFrame
sentences = vocabulary.apply(get_example, axis=1, result_type='expand')
df['example_sentence'] = sentences[0]
df['sentence_with_reading'] = sentences[1]
df['sentence_translation'] = sentences[2]
# df['sentence_translation'] = vocabulary.apply(lambda row: translate(row['Sentence']) if row['Sentence_def'] == 'None' else row['Sentence_def'], axis=1)
df['Kanji'] = True
df
# Out:
#     index   word word_with_reading  \
# 0     落とす    落とす            落[お]とす
# 1     落ちる    落ちる            落[お]ちる
# 2      出す     出す             出[だ]す
# 3      出る     出る             出[で]る
# 4     入れる    入れる            入[い]れる
# 5      入る     入る            入[はい]る
# 6     開ける    開ける            開[あ]ける
# 7      開く     開く            開[ひら]く
# 8     閉める    閉める            閉[し]める
# 9     閉まる    閉まる            閉[し]まる
# 10    つける    つける               つける
# 11     つく     つく                つく
# 12     消す     消す             消[け]す
# 13    消える    消える            消[き]える
# 14     抜く     抜く             抜[ぬ]く
# 15    抜ける    抜ける            抜[ぬ]ける
# 16    割れる    割れる            割[わ]れる
# 17    破れる    破れる           破[やぶ]れる
# 18    痩せる    痩せる            痩[や]せる
# 19   ずいぶん   ずいぶん              ずいぶん
# 20      布      布             布[ぬの]
# 21      袋      袋            袋[ふくろ]
# 22    折れる    折れる            折[お]れる
# 23     折る     折る             折[お]る
# 24      歯      歯              歯[は]
# 25    欠ける    欠ける            欠[か]ける
# 26     張る     張る             張[は]る
# 27    仕舞う    仕舞う           仕舞[しま]う
# 28    掛ける    掛ける            掛[か]ける
# 29  ホッチキス  ホッチキス             ホッチキス
#
#                                            definition  \
# 0   Transitive verb - Godan verb with 'su' ending\...
# 1   Intransitive verb - Ichidan verb\nto fall; to ...
# 2   Transitive verb - Godan verb with 'su' ending\...
# 3   Intransitive verb - Ichidan verb\nto leave; to...
# 4   Transitive verb - Ichidan verb\nto put in; to ...
# 5   Intransitive verb - Godan verb with 'ru' endin...
# 6   Transitive verb - Ichidan verb\nto open (a doo...
# 7   Intransitive verb - Godan verb with 'ku' endin...
# 8   Transitive verb - Ichidan verb\nto close; to shut
# 9   Intransitive verb - Godan verb with 'ru' endin...
# 10  Transitive verb - Ichidan verb\nto attach; to ...
# 11  Intransitive verb - Godan verb with 'ku' endin...
# 12  Transitive verb - Godan verb with 'su' ending\...
# 13  Intransitive verb - Ichidan verb\nto disappear...
# 14  Transitive verb - Godan verb with 'ku' ending\...
# 15  Intransitive verb - Ichidan verb\nto come out;...
# 16  Intransitive verb - Ichidan verb\nto break; to...
# 17  Intransitive verb - Ichidan verb\nto break; to...
# 18  Intransitive verb - Ichidan verb\nto become th...
# 19  Adverb taking the 'to' particle - Adverb (fuku...
# 20             Noun\ncloth; fabric; material; textile
# 21                             Noun\nbag; sack; pouch
# 22  Intransitive verb - Ichidan verb\nto break; to...
# 23  Transitive verb - Godan verb with 'ru' ending\...
# 24                                 Noun\ntooth; teeth
# 25  Intransitive verb - Ichidan verb\nto chip; to ...
# 26  Transitive verb - Godan verb with 'ru' ending\...
# 27  Transitive verb - Godan verb with 'u' ending\n...
# 28  Transitive verb - Ichidan verb\nto hang up (e....
# 29                      Noun\nstapler; paper fastener
#
#                                      example_sentence  \
# 0                                            一つ精油お湯数滴
# 1                                             何度無くなった
# 2                                           行き詰まり洗い出す
# 3                                    昨夜秒速50メートル樹木倒壊する
# 4                                                老い外見
# 5                                      正門前怖い先輩先輩裏門入った
# 6                                             祈る合否開けた
# 7                                       野党各党図る連日会合開いて
# 8                                息子はドアをバタンと閉めて怒りを表わした
# 9                                      窓が閉まっているか確かめとけ
# 10                                         間もない馴染み居場所
# 11                                       仕上げなければ山前ため息
# 12                                騒音に消されて私の声は人に届かなかった
# 13                                     軈て幽霊は濃い霧の中に消えた
# 14                        それは定石通りというだけで手を抜いたわけではないのです
# 15                                      人込みを体を横にして抜けた
# 16                                         騒音で頭が割れそうだ
# 17                                          斜め切れ目入れて皮
# 18                              痩せるためには何かスポーツをしたほうがよい
# 19                                          1年経ち田舎暮らし
# 20                                           財布日無くなって
# 21                                       素敵な手袋をしていますね
# 22  彼は彼女に車を運転させるつもりはなかったのだが彼女があまりにせがむものだから彼の方がとうとう折れた
# 23                                  あそうだに変なことしたら背骨を折る
# 24                                   息子の乳歯が永久歯に変わりました
# 25      西洋人の中には私たちの家屋には彼らが不可欠と考えるもの全てが欠けていると思う人もいるだろう
# 26                                       川の近くにテントを張った
# 27                               息子はあの棚の上の本を全て読んでしまった
# 28                  身命をかけて職務を実践しすべての警察官の心に火をともしてくれました
# 29                                    ホッチキスを貸してくれませんか
#
#                                 sentence_with_reading  \
# 0                         一つ[ひと]精油[せいゆ]お湯[おゆ]数滴[すうてき]
# 1                                     何度[なんど]無くなった[な]
# 2                                行き詰まり[いきづ]洗い出す[あらいだ]
# 3      昨夜[さくや]秒速[びょうそく]50メートル[ごじゅう]樹木[じゅもく]倒壊する[とうかい]
# 4                                       老い[お]外見[がいけん]
# 5    正門前[せいもんまえ]怖い[こわ]先輩[せんぱい]先輩[せんぱい]裏門[うらもん]入った[はい]
# 6                                 祈る[いの]合否[ごうひ]開けた[あ]
# 7          野党各党[やとうかくとう]図る[はか]連日[れんじつ]会合[かいごう]開いて[ひら]
# 8               息子[むすこ]はドアをバタンと閉めて[し]怒り[いか]を表わした[あらわ]
# 9                          窓[まど]が閉まっている[しま]か確かめ[たし]とけ
# 10                            間もない[ま]馴染み[なじ]居場所[いばしょ]
# 11                     仕上げなければ[しあ]山[やま]前[まえ]ため息[ためいき]
# 12      騒音[そうおん]に消されて[け]私の[わたし]声[こえ]は人[ひと]に届かなかった[とど]
# 13             軈て[やが]幽霊[ゆうれい]は濃い[こ]霧[きり]の中[なか]に消えた[き]
# 14        それは定石[じょうせき]通り[どお]というだけで手を抜いた[てをぬ]わけではないのです
# 15                          人込みを体[からだ]を横[よこ]にして抜けた[ぬ]
# 16                           騒音[そうおん]で頭[あたま]が割れ[わ]そうだ
# 17                          斜め[なな]切れ目[きれめ]入れて[い]皮[かわ]
# 18                       痩せる[や]ためには何か[なに]スポーツをしたほうがよい
# 19                           1年[いちねん]経ち[た]田舎暮らし[いなかぐ]
# 20                                財布[さいふ]日[ひ]無くなって[な]
# 21                            素敵な[すてき]手袋[てぶくろ]をしていますね
# 22  彼[かれ]は彼女[かのじょ]に車[くるま]を運転させる[うんてん]つもりはなかったのだが彼女...
# 23                      あそうだに変な[へん]ことしたら背骨[せぼね]を折る[お]
# 24             息子[むすこ]の乳歯[にゅうし]が永久歯[えいきゅうし]に変わりました[か]
# 25  西洋人[せいようじん]の中[なか]には私たち[わたし]の家屋[かおく]には彼ら[かれ]が不可...
# 26                            川[かわ]の近く[ちか]にテントを張った[は]
# 27       息子[むすこ]はあの棚[たな]の上の[うえ]本[ほん]を全て[すべ]読んで[よ]しまった
# 28  身命[しんめい]をかけて職務[しょくむ]を実践[じっせん]しすべての警察官[けいさつかん]の...
# 29                                 ホッチキスを貸して[か]くれませんか
#
#                                  sentence_translation  Kanji   v1 word_audio  \
# 0   One way to enjoy aromatherapy is to place a fe...   True  NaN        NaN
# 1   I kept failing the exam time after time and ev...   True  NaN        NaN
# 2   If you are feeling stuck in your current state...   True  NaN        NaN
# 3   Last night’s ferocious typhoon, with a maximum...   True  NaN        NaN
# 4   As you age, it is natural to develop wrinkles ...   True  NaN        NaN
# 5   There was a scary senior student in front of t...   True  NaN        NaN
# 6   I opened  the sealed envelope informing me of ...   True  NaN        NaN
# 7   Opposition political parties are meeting daily...   True  NaN        NaN
# 8   The son demonstrated his anger by shutting the...   True  NaN        NaN
# 9                      See that the window is closed.   True  NaN        NaN
# 10  Even though I transferred to a new school only...   True  NaN        NaN
# 11  The student breathed out a sigh of anguish at ...   True  NaN        NaN
# 12      I couldn't make myself heard above the noise.   True  NaN        NaN
# 13  Before long, the ghost disappeared into a thic...   True  NaN        NaN
# 14  That's just standard practise, it's not like t...   True  NaN        NaN
# 15               He edged sideways through the crowd.   True  NaN        NaN
# 16               My head is splitting from the noise.   True  NaN        NaN
# 17  Make diagonal slits in the sausage before gril...   True  NaN        NaN
# 18  In order to lose weight you had better take up...   True  NaN        NaN
# 19  It has been a year since I moved here, and I h...   True  NaN        NaN
# 20  I left my wallet in the classroom. It was no l...   True  NaN        NaN
# 21                 Those are nice gloves you have on.   True  NaN        NaN
# 22  He didn't intend to let her drive but she pest...   True  NaN        NaN
# 23  One more thing. If you try anything on Mayu I'...   True  NaN        NaN
# 24                   All my son's adult teeth are in.   True  NaN        NaN
# 25  Some Westerners may think our houses are lacki...   True  NaN        NaN
# 26              We set up the tent next to the river.   True  NaN        NaN
# 27          My son has read every book on that shelf.   True  NaN        NaN
# 28  He risked his life to carry out his duty and i...   True  NaN        NaN
# 29                 Will you please lend me a stapler?   True  NaN        NaN
#
#    setence_audio
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN

# %%
df.to_csv('../../data/vocab.csv', encoding="utf-8", index=False, header=False)

# %%
from jisho_api.word import Word
r = Word.request('仕舞う')

# %%
senses = r.data[0].senses
meanings = []
for sense in senses:
    english_definitions = sense.english_definitions
    meanings.append(english_definitions)
    
meanings
# Out:
# [['to finish', 'to stop', 'to end', 'to put an end to', 'to bring to a close'],
#  ['to close (a business, etc.)',
#   'to close down',
#   'to shut down',
#   'to shut up'],
#  ['to put away', 'to put back', 'to keep', 'to store'],
#  ['to do completely', 'to finish'],
#  ['to do accidentally', 'to do without meaning to', 'to happen to do']]

# %%
x = r.data[0].senses[0].english_definitions
result = ""
for item in x:
    result += f"{item}; "
    
result[:-2]
# Out:
# 'to finish; to stop; to end; to put an end to; to bring to a close'

# %%
r.data
# Out:
# [WordConfig(slug='仕舞う', is_common=True, tags=[], jlpt=['jlpt-n3', 'jlpt-n1'], japanese=[Japanese(word='仕舞う', reading='しまう'), Japanese(word='終う', reading='しまう'), Japanese(word='了う', reading='しまう'), Japanese(word='蔵う', reading='しまう')], senses=[Sense(english_definitions=['to finish', 'to stop', 'to end', 'to put an end to', 'to bring to a close'], parts_of_speech=["Godan verb with 'u' ending", 'Transitive verb'], links=[], tags=['Usually written using kana alone'], restrictions=[], see_also=[], antonyms=[], source=[], info=[]), Sense(english_definitions=['to close (a business, etc.)', 'to close down', 'to shut down', 'to shut up'], parts_of_speech=["Godan verb with 'u' ending", 'Transitive verb'], links=[], tags=['Usually written using kana alone'], restrictions=[], see_also=[], antonyms=[], source=[], info=[]), Sense(english_definitions=['to put away', 'to put back', 'to keep', 'to store'], parts_of_speech=["Godan verb with 'u' ending", 'Transitive verb'], links=[], tags=['Usually written using kana alone'], restrictions=[], see_also=[], antonyms=[], source=[], info=[]), Sense(english_definitions=['to do completely', 'to finish'], parts_of_speech=['Auxiliary verb', "Godan verb with 'u' ending"], links=[], tags=['Usually written using kana alone'], restrictions=[], see_also=[], antonyms=[], source=[], info=['after the -te form of a verb']), Sense(english_definitions=['to do accidentally', 'to do without meaning to', 'to happen to do'], parts_of_speech=['Auxiliary verb', "Godan verb with 'u' ending"], links=[], tags=['Usually written using kana alone'], restrictions=[], see_also=[], antonyms=[], source=[], info=['after the -te form of a verb'])]),
#  WordConfig(slug='仕舞うた屋', is_common=False, tags=[], jlpt=[], japanese=[Japanese(word='仕舞うた屋', reading='しもうたや'), Japanese(word='仕舞屋', reading='しもうたや')], senses=[Sense(english_definitions=['store that has been gone out of business', 'household that lives without carrying on a business'], parts_of_speech=['Noun'], links=[], tags=[], restrictions=[], see_also=[], antonyms=[], source=[], info=[])]),
#  WordConfig(slug='仕舞うた', is_common=False, tags=[], jlpt=[], japanese=[Japanese(word='仕舞うた', reading='しもうた')], senses=[Sense(english_definitions=['darn it!', 'darn!', 'oops!', 'oh dear!', 'oh no!'], parts_of_speech=['Expressions (phrases, clauses, etc.)'], links=[], tags=['Usually written using kana alone', 'Kansai dialect'], restrictions=[], see_also=['しまった'], antonyms=[], source=[], info=[])])]

# %%
# Assuming r is the return value from Word.request('降りる')
senses = r.data[0].senses[0]

# Extract parts_of_speech for each sense

parts_of_speech = senses.parts_of_speech
if len(parts_of_speech) == 1:
    print(f"{parts_of_speech[0]}")
else:
    print(f"{parts_of_speech[1]} - {parts_of_speech[0]}")
# Out:
# Transitive verb - Godan verb with 'u' ending
